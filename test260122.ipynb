# %%
import open3d as o3d
import open3d_tutorial as o3dtut
import numpy as np
import matplotlib.pyplot as plt

# %%
pcl = o3d.io.read_point_cloud("fragment.ply")
hull, _ = pcl.compute_convex_hull()
hull_ls = o3d.geometry.LineSet.create_from_triangle_mesh(hull)
#hull_ls.paint_uniform_color([1,0,0])
o3d.visualization.draw_geometries([pcl,hull_ls])
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1061 at 0x20BA76B57F0>

# %%
pcd = o3d.io.read_point_cloud("sphere.ply")
hull, _ = pcd.compute_convex_hull()
hull_ls = o3d.geometry.LineSet.create_from_triangle_mesh(hull)
o3d.visualization.draw_geometries([pcd,hull_ls])
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1061 at 0x20BA76A18E0>
